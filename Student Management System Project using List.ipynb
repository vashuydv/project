# %%
#Student Management System Project using List
students = []

def add_student():
    name = input("Enter student name: ")
    age = input("Enter student age: ")
    student = {"name": name, "age": age}
    students.append(student)
    print("Student added successfully.")

def display_students():
    if not  students:
        print("No students found.")
    else:
        print("List of students:")
        for student in students:
            print(f"Name: {student['name']}, Age: {student['age']}")

def search_student():
    
    name = input("Enter student name to search: ")
    found = False
    for student in students:
        if student['name'] == name:
            print(f"Name: {student['name']}, Age: {student['age']}")
            found = True
    if not found:
        print("Student not found.")

def remove_student():
    name = input("Enter student name to remove: ")
    found = False
    for student in students:
        if student['name'] == name:
            students.remove(student)
            found = True
            print("Student removed successfully.")
            break
    if not found:
        print("Student not found.")

def main():
    while True:
        print("\nStudent Management System")
        print("1. Add Student")
        print("2. Display Students")
        print("3. Search Student")
        print("4. Remove Student")
        print("5. Exit")
        choice = input("Enter your choice (1-5): ")
        
        if choice == '1':
            add_student()
        elif choice == '2':
            display_students()
        elif choice == '3':
            search_student()
        elif choice == '4':
            remove_student()
        elif choice == '5':
            print("Exiting the program...")
            break
        else:
            print("Invalid choice. Please try again.")

if __name__ == "__main__":
    main()
# Out:
# Student Management System
# 1. Add Student
# 2. Display Students
# 3. Search Student
# 4. Remove Student
# 5. Exit
# Enter your choice (1-5): 1
# Enter student admission number: 12
# Enter student name: vashu
# Enter student age: 22
# Student added successfully.
#
# Student Management System
# 1. Add Student
# 2. Display Students
# 3. Search Student
# 4. Remove Student
# 5. Exit
# Enter your choice (1-5): 2
# List of students:
# Name: vashu, Age: 22
#
# Student Management System
# 1. Add Student
# 2. Display Students
# 3. Search Student
# 4. Remove Student
# 5. Exit
# Enter your choice (1-5): 3
# Enter student name to search: 12
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 69
#      66             print("Invalid choice. Please try again.")
#      68 if __name__ == "__main__":
# ---> 69     main()
#
# Cell In[2], line 59, in main()
#      57     display_students()
#      58 elif choice == '3':
# ---> 59     search_student()
#      60 elif choice == '4':
#      61     remove_student()
#
# Cell In[2], line 27, in search_student()
#      25 for student in students:
#      26     if student['admission_number'] == admission_number:
# ---> 27         print(f"admission_number: {student[admission_number]}, Name: {student['name']}, Age: {student['age']}")
#      28         found = True
#      29 if not found:
#
# KeyError: 12
